# %%
import pandas as pd

df = pd.read_csv('/home/eva/Downloads/proportions', delimiter = ' ', names = ['prop'])
df
# Out:
#               prop
# 0     3.654855e-02
# 1     1.375091e-02
# 2     8.394113e-03
# 3     5.941778e-03
# 4     4.560262e-03
# ...            ...
# 4415  2.883961e-07
# 4416  2.874035e-07
# 4417  2.881615e-07
# 4418  2.856910e-07
# 4419  2.871933e-07
#
# [4420 rows x 1 columns]

# %%
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

# Define the function you want to fit
def func(x, b):
    return  np.log(x)**b

# Your data as x and y pairs
x_data = xs
y_data = list(df['prop'])

# Find the best-fit parameters
#popt, pcov = curve_fit(func, x_data, y_data, maxfev=100000)

# Get the best-fit values for a and b
#b = popt

# Print the results
print("Best-fit values:")
print(" b = {b}")

# Plot the original data and the fitted curve
plt.scatter(x_data, y_data, label="Original data", marker='o')
#plt.plot(x_data, func(x_data, a, b), 'r-', label="Fitted curve")
plt.legend()
plt.show()
# Out:
# Best-fit values:
#  b = {b}

# %%
df[3421:]

xs = [x*10**9 for x in range(0,3421)] + [x*10**9 for x in range(19000,19999)]

# %%
import pandas as pd
from sympy import primepi

num = 0
primes = 0
ratio = []
for i in range(0,400):
    s = str(i).zfill(5)
    df = pd.read_csv(f'/run/media/eva/BACKUP/primefiles/pf/prime_all_{s}', names = ['cond','a1','a2','a3','a4','a6','sign'])
    df['cond'] = df['cond'].str.replace("[","")
    
    num += len(df['cond'].unique())
    primes += primepi((i+1)*10**9) 
    ratio.append(num/primes)

    
print(ratio)
# Out:
# /tmp/ipykernel_6388/577577638.py:10: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['cond'] = df['cond'].str.replace("[","")
# /tmp/ipykernel_6388/577577638.py:10: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['cond'] = df['cond'].str.replace("[","")
# /tmp/ipykernel_6388/577577638.py:10: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['cond'] = df['cond'].str.replace("[","")
# ...

# %%
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import seaborn as sns

# Define the curve function
def curve_function(x, a, b):
    return x**a * np.log(x)**b

# Create some example data (x_data, y_data)
x_data = [(x+1)*10**9 for x in range(0,362) ]
y_data = ratio

# Perform curve fitting
params, params_covariance = curve_fit(curve_function, x_data, y_data, p0=[1, 1])

# Print the best-fit parameters
print("a =", params[0], ", b =", params[1])
sns.set(style="whitegrid")
# Plot the data and the best-fit curve
x_fit = [(x+1)*10**9 for x in range(0,362)]
y_fit = curve_function(x_fit, params[0], params[1])

plt.scatter(x_data, y_data, label='Data', color='red')
plt.plot(x_fit, y_fit, label='Best-fit curve', color='blue')
plt.legend()
plt.show()
# Out:
# a = -1.2905667749853118 , b = 7.726914131128929
